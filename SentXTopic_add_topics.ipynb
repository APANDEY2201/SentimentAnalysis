# %%
import pandas as pd
import pickle

# %%
#pickle_in = open("xx_yy.pickle", "rb")
pd.set_option('display.max_columns', None)
pickle_in101 = open("Data\\cleaned_18Topics.df", "rb")
sample_data = pickle.load(pickle_in101)

# %%
unpickled_df = pd.DataFrame(sample_data)

# %%
unpickled_df.head(10)
# Out:
# 0                            Org   OrgSector   RverMonthYear RverReviewer  \
# 1   Instone Real Estate Group AG  Immobilien        May 2020            1
# 2   Instone Real Estate Group AG  Immobilien        May 2020            2
# 3   Instone Real Estate Group AG  Immobilien        May 2020            3
# 4   Instone Real Estate Group AG  Immobilien    October 2019            4
# 5   Instone Real Estate Group AG  Immobilien    October 2019            5
# 6   Instone Real Estate Group AG  Immobilien  September 2019            6
# 7   Instone Real Estate Group AG  Immobilien     August 2019            8
# 8   Instone Real Estate Group AG  Immobilien       July 2019            9
# 9   Instone Real Estate Group AG  Immobilien       July 2019            1
# 10  Instone Real Estate Group AG  Immobilien        May 2019            2
#
# 0                        RverPosition  \
# 1          Führungskraft / Management
# 2      Angestellte/r oder Arbeiter/in
# ...

# %%
unpickled_df['workAtmos_cumul'] = unpickled_df['topic2'] + unpickled_df['topic16']+unpickled_df['topic17']

# %%
unpickled_df.head(10)
# Out:
# 0                            Org   OrgSector   RverMonthYear RverReviewer  \
# 1   Instone Real Estate Group AG  Immobilien        May 2020            1
# 2   Instone Real Estate Group AG  Immobilien        May 2020            2
# 3   Instone Real Estate Group AG  Immobilien        May 2020            3
# 4   Instone Real Estate Group AG  Immobilien    October 2019            4
# 5   Instone Real Estate Group AG  Immobilien    October 2019            5
# 6   Instone Real Estate Group AG  Immobilien  September 2019            6
# 7   Instone Real Estate Group AG  Immobilien     August 2019            8
# 8   Instone Real Estate Group AG  Immobilien       July 2019            9
# 9   Instone Real Estate Group AG  Immobilien       July 2019            1
# 10  Instone Real Estate Group AG  Immobilien        May 2019            2
#
# 0                        RverPosition  \
# 1          Führungskraft / Management
# 2      Angestellte/r oder Arbeiter/in
# ...

# %%
df_new = unpickled_df[['topic0','topic1','topic2','topic3','topic4','topic5','topic6','topic7','topic8','topic9','topic10','topic11','topic12','topic13','topic14','topic15','topic16','topic17','workAtmos_cumul']]

# %%
df_new.head(3)
# Out:
# 0     topic0     topic1     topic2     topic3     topic4     topic5  \
# 1  0.0357143  0.0357143  0.0357143  0.0357143  0.0357143  0.0357143
# 2  0.0357143  0.0357143  0.0357143  0.0357143  0.0357143  0.0357143
# 3    0.14189          0          0          0          0          0
#
# 0     topic6     topic7     topic8     topic9    topic10    topic11  \
# 1  0.0357143  0.0357143  0.0357143  0.0357143  0.0357143  0.0357143
# 2  0.0357143  0.0357143  0.0357143  0.0357143  0.0357143  0.0357143
# 3   0.337175          0   0.141891          0          0          0
#
# 0    topic12    topic13   topic14    topic15    topic16    topic17  \
# 1  0.0357143  0.0357143  0.392857  0.0357143  0.0357143  0.0357143
# 2  0.0357143  0.0357143  0.392857  0.0357143  0.0357143  0.0357143
# 3          0   0.141893         0          0  0.0817442  0.0743245
#
# 0 workAtmos_cumul
# 1        0.107143
# 2        0.107143
# 3        0.156069

# %%
df_new = df_new.astype(float)
df_new.head(2)
# Out:
# 0    topic0    topic1    topic2    topic3    topic4    topic5    topic6  \
# 1  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714
# 2  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714
#
# 0    topic7    topic8    topic9   topic10   topic11   topic12   topic13  \
# 1  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714
# 2  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714
#
# 0   topic14   topic15   topic16   topic17  workAtmos_cumul
# 1  0.392857  0.035714  0.035714  0.035714         0.107143
# 2  0.392857  0.035714  0.035714  0.035714         0.107143

# %%
df_new['max_score'] = df_new.idxmax(axis=1)

# %%
df_new['max_score'].value_counts()
# Out:
# workAtmos_cumul    4620
# topic14            2071
# topic0             1836
# topic5             1555
# topic11            1539
# topic7             1318
# topic4             1220
# topic15             984
# topic10             917
# topic3              895
# topic6              883
# topic8              739
# topic1              738
# topic13             616
# topic12             587
# topic9              367
# topic16              65
# topic17              33
# topic2               14
# Name: max_score, dtype: int64

# %%
df_new2=df_new

# %%
df_new2.drop(columns=['max_score'], inplace=True)

# %%
df_new2
# Out:
# 0        topic0    topic1    topic2    topic3    topic4    topic5    topic6  \
# 1      0.035714  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714
# 2      0.035714  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714
# 3      0.141890  0.000000  0.000000  0.000000  0.000000  0.000000  0.337175
# 4      0.000000  0.224638  0.000000  0.000000  0.000000  0.000000  0.000000
# 5      0.011364  0.011364  0.011364  0.193402  0.011364  0.352260  0.011364
# ...         ...       ...       ...       ...       ...       ...       ...
# 20993  0.026316  0.026316  0.026316  0.026316  0.026316  0.026316  0.026316
# 20994  0.017241  0.017241  0.017241  0.017241  0.017241  0.017244  0.017241
# 20995  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714
# 20996  0.026316  0.026316  0.289473  0.289474  0.026316  0.026316  0.026316
# 20997  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714
#
# ...

# %%
df_new2 = df_new2.astype(float)
df_new2['max_score'] = df_new2.idxmax(axis=1)

# %%
df_new2.head(2)
# Out:
# 0    topic0    topic1    topic2    topic3    topic4    topic5    topic6  \
# 1  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714
# 2  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714
#
# 0    topic7    topic8    topic9   topic10   topic11   topic12   topic13  \
# 1  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714
# 2  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714
#
# 0   topic14   topic15   topic16   topic17  workAtmos_cumul max_score
# 1  0.392857  0.035714  0.035714  0.035714         0.107143   topic14
# 2  0.392857  0.035714  0.035714  0.035714         0.107143   topic14

# %%
df_new2['max_score'].value_counts()
# Out:
# workAtmos_cumul    4620
# topic14            2071
# topic0             1836
# topic5             1555
# topic11            1539
# topic7             1318
# topic4             1220
# topic15             984
# topic10             917
# topic3              895
# topic6              883
# topic8              739
# topic1              738
# topic13             616
# topic12             587
# topic9              367
# topic16              65
# topic17              33
# topic2               14
# Name: max_score, dtype: int64

# %%
# df3 for average
df3 = df_new
df3.head(2)
df_new.head(2)
# Out:
# 0    topic0    topic1    topic2    topic3    topic4    topic5    topic6  \
# 1  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714
# 2  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714
#
# 0    topic7    topic8    topic9   topic10   topic11   topic12   topic13  \
# 1  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714
# 2  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714  0.035714
#
# 0   topic14   topic15   topic16   topic17  workAtmos_cumul
# 1  0.392857  0.035714  0.035714  0.035714         0.107143
# 2  0.392857  0.035714  0.035714  0.035714         0.107143

# %%
df3['workAtmos_avg'] = (df3['topic2'] + df3['topic16']+df3['topic17'])/3

# %%
df3.drop(columns=['workAtmos_cumul'], inplace=True)

# %%
df3.drop(columns=['topic2','topic16','topic17'], inplace=True)

# %%
df3['workAtmos_avg'] = df3.idxmax(axis=1)

# %%
df3['workAtmos_avg'].value_counts()
# Out:
# topic14          2649
# topic0           2564
# topic5           1792
# topic11          1669
# topic7           1620
# topic4           1474
# topic3           1285
# topic15          1182
# topic10          1038
# topic6            992
# topic1            978
# workAtmos_avg     941
# topic8            940
# topic12           706
# topic13           703
# topic9            464
# Name: workAtmos_avg, dtype: int64

# %%
unpickled_df.columns
# Out:
# RangeIndex(start=0, stop=32, step=1)

# %%
# rename columns to header (first row in dataframe)
new_columns=unpickled_df.loc[0]

# %%
new_columns
# Out:
# 0               Org
# 1         OrgSector
# 2     RverMonthYear
# 3      RverReviewer
# 4      RverPosition
# 5           RverLoc
# 6         RverRecom
# 7     RvReviewAbout
# 8           RvScore
# 9         RvComment
# 10           topic0
# 11           topic1
# 12           topic2
# 13           topic3
# 14           topic4
# 15           topic5
# 16           topic6
# 17           topic7
# 18           topic8
# 19           topic9
# 20          topic10
# 21          topic11
# 22          topic12
# 23          topic13
# 24          topic14
# 25          topic15
# 26          topic16
# 27          topic17
# 28          topic18
# 29          topic19
# 30          topic20
# 31          topic21
# Name: 0, dtype: object

# %%
unpickled_df.columns = new_columns

# %%
unpickled_df = unpickled_df[1:]

# %%
unpickled_df['RvComment'][1]
# Out:
# ' Top Arbeitgeber mit vielen Benefiz      Transparente und regelmäßige Infos und Austausch mit dem Vorstand   '

# %%
serLen = unpickled_df['RvComment'].size

# %%
serLen
# Out:
# 20997

# %%
sentiment_df=pd.read_pickle('sentiment_score_reviews.data')

# %%
sentiment_df['summation']= sentiment_df['score']*sentiment_df['topic21']+sentiment_df['score']*sentiment_df['topic20']

# %%
sentiment_df.head(2)
# Out:
# 0                           Org   OrgSector RverMonthYear RverReviewer  \
# 1  Instone Real Estate Group AG  Immobilien      May 2020            1
#
# 0                RverPosition  \
# 1  Führungskraft / Management
#
# 0                                            RverLoc  RverRecom RvReviewAbout  \
# 1  Hat zum Zeitpunkt der Bewertung im Bereich Fin...  Empfohlen       Overall
#
# 0 RvScore                                          RvComment  ...  topic14  \
# 1     4.9   Top Arbeitgeber mit vielen Benefiz      Trans...  ...  0.34375
#
# 0  topic15  topic16  topic17  topic18  topic19  topic20  topic21   score  \
# 1  0.03125  0.03125  0.03125  0.03125  0.03125  0.03125  0.03125  0.3266
#
# 0  summation
# 1  0.0204125
#
# [1 rows x 34 columns]

# %%
summat=0
average_var = 0
for i in range(0, 22):
    col_name='topic'+str(i)
    sum0=sentiment_df['score']*sentiment_df[col_name]
    summat=summat+sum0
    print('sum0', sum0)
    
print(summat)
# Out:
# sum0 1    0.0102063
# dtype: object
# sum0 1    0.0102063
# dtype: object
# sum0 1    0.0102063
# dtype: object
# sum0 1    0.0102063
# dtype: object
# sum0 1    0.0102063
# dtype: object
# sum0 1    0.0102063
# dtype: object
# sum0 1    0.0102063
# dtype: object
# sum0 1    0.0102063
# dtype: object
# sum0 1    0.0102063
# dtype: object
# sum0 1    0.0102063
# dtype: object
# sum0 1    0.0102063
# dtype: object
# sum0 1    0.0102063
# dtype: object
# sum0 1    0.0102063
# dtype: object
# sum0 1    0.0102063
# dtype: object
# sum0 1    0.112269
# dtype: object
# sum0 1    0.0102063
# dtype: object
# sum0 1    0.0102063
# dtype: object
# sum0 1    0.0102063
# dtype: object
# sum0 1    0.0102063
# dtype: object
# sum0 1    0.0102063
# dtype: object
# sum0 1    0.0102063
# dtype: object
# sum0 1    0.0102063
# dtype: object
# 1    0.3266
# dtype: object

# %%
col_name=[]
for i in range(0, 23):
    col_name.append('topic'+str(i))
print("'",col_name,"',")
# Out:
# ' ['topic0', 'topic1', 'topic2', 'topic3', 'topic4', 'topic5', 'topic6', 'topic7', 'topic8', 'topic9', 'topic10', 'topic11', 'topic12', 'topic13', 'topic14', 'topic15', 'topic16', 'topic17', 'topic18', 'topic19', 'topic20', 'topic21', 'topic22'] ',

# %%
u = sentiment_df.iloc[10:31]
v = sentiment_df[['score']]

# %%
u
# Out:
# Empty DataFrame
# Columns: [Org, OrgSector, RverMonthYear, RverReviewer, RverPosition, RverLoc, RverRecom, RvReviewAbout, RvScore, RvComment, topic0, topic1, topic2, topic3, topic4, topic5, topic6, topic7, topic8, topic9, topic10, topic11, topic12, topic13, topic14, topic15, topic16, topic17, topic18, topic19, topic20, topic21, score, summation]
# Index: []
#
# [0 rows x 34 columns]
